# %% [markdown]
# # 9th Session

# %% [markdown]
# # Axioms of rationality part 3

# %% [markdown]
# $$
# \text{Consumption Plan or Consumption Bundle: } \bold{x} = (x_1, x_2, \dots, x_n)
# $$

# %% [markdown]
# $$
# \text{A consumption bundle} \bold{x} \in X \text{ is thus represented by a point } \bold{x} \in R^n_{+}.
# $$
#
# $$ \text{ So } X = R^n_{+} $$

# %% [markdown]
# ## Properties of The Consumption set, X
#
# The minimal requirements on the consumption are
#
# 1. $$ X \subseteq R^n_{+}$$
#
# 2. $$ X \text{ is closed} $$
#
# 3. $$ X \text{ is convex} $$
#
# 4. $$ \bold{0} \in X $$

# %% [markdown]
# Feasible set $\mathit{B}$ is that subset of the consumption set $\mathit{X}$ that remains after we have accounted for any constraints on the consumer's access to commodities due to the practical, institutional, or economic realities of the world. To put it simply, assume $\mathit{B} \subset \mathit{X}$.

# %% [markdown]
# A **preference relation** typically specifies the limits, if any, on the consumer’s ability to perceive in situations involving choice the form of consistency or inconsistency in the consumer’s choices, and information about the consumer’s tastes for the different objects of choice.

# %% [markdown]
# Finally, the model is ‘closed’ by specifying some **behavioural assumption**. This expresses the guiding principle the consumer uses to make final choices and so identifies the ultimate objectives in choice. *It is supposed that the consumer seeks to identify and select an available alternative that is most preferred in the light of his personal tastes.*

# %% [markdown]
# **axioms of consumer** choice formalise the view that the consumer can choose and that choices are consistent in a particular way.

# %% [markdown]
# Formally, we represent the consumer’s preferences by a binary relation, $\succsim$, defined on the consumption set, $X$. If $x^1 \succsim x^2$, we say that ‘$x^1$ is at least as good as $x^2$’ for this consumer.

# %% [markdown]
# $$
# \text{Axiom 1: Completeness. For all } x^1 \text{ and } x^2 \text{ in } X, \text{ either } x^1 \succsim x^2 \text{ or } x^2 \succsim x^1.
# $$

# %% [markdown]
# $$
# \text{Axiom 2: Transitivity. For any three elements } x^1, x^2 \text{ and } x^3 \text{ in } X, \text{if } x^1 \succsim x^2 \text{ and } x^2 \succsim x^3, \text{ then } x^1 \succsim x^3
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch

# Define the vertices for the original curve
vertices_curve = [
    (0, 10),     
    (0.1, 10),   
    (0.15, 10),  
    (0.25, 9.75)   
]

vertices1 = [
    (0.25, 9.75),  
    (0.4, 10),  
    (0.5, 10),  
    (0.85, 9)       
]

vertices2 = [
    (0.85, 9),      
    (0.6, 8.8),  
    (0.4, 8),  
    (0.25, 9.75)  
]

vertices_line1 = [
    (0.85, 9),    
    (1, 9),      
    (1, 8.7),      
    (1.1, 9)      
]

vertices_line2 = [
    (1.1, 9),    
    (1.3, 9.5),      
    (1.2, 7),      
    (2, 8)       
]

vertices_line3 = [
    (2, 8),    
    (2.8, 9),      
    (4, 9),      
    (3, 9.5)       
]

vertices_line4 = [
    (3, 9.5),    
    (2.2, 10),      
    (4, 10),      
    (4, 9.5)       
]

vertices = vertices_curve + vertices1 + vertices2 + vertices_line1 + vertices_line2 + vertices_line3 + vertices_line4

# Define the codes for the path
codes = [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO]

# Create the path and patch for the curve
path_curve = Path(vertices_curve, codes[:4])
curve_patch = PathPatch(path_curve, facecolor='none', lw=2, edgecolor='blue')

path_gap = Path(vertices1 + vertices2, codes[4:12])
gap_patch = PathPatch(path_gap, facecolor='none', lw=2, edgecolor='blue', linestyle='--')

path_lines = Path(vertices_line1 + vertices_line2 + vertices_line3 + vertices_line4, codes[12:])
lines_patch = PathPatch(path_lines, facecolor='none', lw=2, edgecolor='blue')

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Add the patches to the axes
ax.add_patch(curve_patch)
ax.add_patch(gap_patch)
ax.add_patch(lines_patch)

# Add text annotations
plt.text(2, 10, r'$\succ \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(0.5, 8, r'$\prec \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(0.7, 9.3, r'$\sim (\mathbf{x}^0)$', fontsize=12, color='black', ha='right', va='top')
plt.scatter(1.15, 9.06, color='#549A40')
plt.annotate(r'$\mathbf{x}^0$', (1.15, 9.), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')


# Set the axis limits and labels
ax.set_xlim(0, 4)
ax.set_ylim(7, 11)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_title('Hypothetical preferences satisfying Axioms 1 and 2.')
plt.show()

# %% [markdown]
# ### Definition 1.1 Preference Relation
#
# *The binary relation $\succsim$ on the consumption set X is called a preference relation if it satisfies Axioms 1 and 2.*

# %% [markdown]
# ### Definition 1.2 Strict Preference Relation
#
# *The binary relation $\succ$ on the consumption set X is defined as follows:*
#
# $$
# \bold{x}^1 \succ \bold{x}^2 \mathit{\text{ if and only if }} x^1 \succsim x^2 \text{ and } x^2 \nsucceq x^1.
# $$
#
# *The relation $\succ$ is called the strict preference relation induced by $\succsim$ , or simply the strict preference relation when $\succsim$ is clear. The phrase $\bold{x}^1$ $\succ$ $\bold{x}^2$ is read, ‘$\bold{x}^1$ is strictly preferred to $\bold{x}^2$’.*

# %% [markdown]
# ### Definition 1.3 Indifference Relation
#
# *The binary relation $\sim$ on the consumption set X is defined as follows:*
#
# $$
# \bold{x}^1 \sim \bold{x}^2 \mathit{\text{ if and only if }} x^1 \succsim x^2 \text{ and } x^2 \succsim x^1.
# $$
#
# *The relation $\sim$ is called the indifference relation induced by $\succsim$ , or simply the indifference
# relation when $\succsim$ is clear. The phrase $\bold{x}^1$ $\sim$ $\bold{x}^2$ is read, ‘$\bold{x}^1$ is indifferent to $\bold{x}^2$’*

# %% [markdown]
# $$
# \text{Axiom 3: Continuity. For all } \bold{x} \in R^n_{+}, \text{the 'at least as good as' set, } \succsim \bold{(x)}, \text{and the 'no better than' set}, \precsim \bold{(x)} \text{ are closed in } R^n_{+}.
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.patches import PathPatch

# Define the vertices for the original curve
vertices_curve = [
    (0, 10),     
    (0.1, 10),   
    (0.15, 10),  
    (0.25, 9.75)   
]

vertices1 = [
    (0.25, 9.75),  
    (0.4, 10),  
    (0.5, 10),  
    (0.85, 9)       
]

vertices2 = [
    (0.85, 9),      
    (0.6, 8.8),  
    (0.4, 8),  
    (0.25, 9.75)   
]

vertices_line1 = [
    (0.85, 9),    
    (1, 9),      
    (1, 8.7),      
    (1.1, 9)       
]

vertices_line2 = [
    (1.1, 9),    
    (1.3, 9.5),      
    (1.2, 7),      
    (2, 8)       
]

vertices_line3 = [
    (2, 8),    
    (2.8, 9),      
    (4, 9),      
    (3, 9.5)       
]

vertices_line4 = [
    (3, 9.5),    
    (2.2, 10),      
    (4, 10),      
    (4, 9.5)       
]

vertices = vertices_curve + vertices1 + vertices2 + vertices_line1 + vertices_line2 + vertices_line3 + vertices_line4

codes = [Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.CURVE4,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO,
         Path.MOVETO, Path.CURVE4, Path.CURVE4, Path.LINETO]

path_curve = Path(vertices_curve, codes[:4])
curve_patch = PathPatch(path_curve, facecolor='none', lw=2, edgecolor='blue')

# Create the path and patch for vertices1 and vertices2
path_gap = Path(vertices1 + vertices2, codes[4:12])
gap_patch = PathPatch(path_gap, facecolor='none', lw=2, edgecolor='blue', linestyle='-')

# Create the path and patch for the line segments
path_lines = Path(vertices_line1 + vertices_line2 + vertices_line3 + vertices_line4, codes[12:])
lines_patch = PathPatch(path_lines, facecolor='none', lw=2, edgecolor='blue')

# Create the figure and axes
fig, ax = plt.subplots(figsize=(8, 6))

# Add the patches to the axes
ax.add_patch(curve_patch)
ax.add_patch(gap_patch)
ax.add_patch(lines_patch)

# Add text annotations
plt.text(2, 10, r'$\succ \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(0.5, 8, r'$\prec \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.scatter(1.15, 9.06, color='#549A40')
plt.annotate(r'$\mathbf{x}^0$', (1.15, 9.), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')

circle = plt.Circle((0.5, 9.3), 0.15, color='red', fill=True, alpha = 0.4)  
plt.gca().add_artist(circle)
plt.text(0.5, 9.35, r'$\mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(0.5, 9.25, r'$\varepsilon$', fontsize=12, color='black', ha='center', va='center', fontweight='bold')

ax.set_xlim(0, 4)
ax.set_ylim(7, 11)
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_title('Hypothetical preferences satisfying Axioms 1, 2, and 3')
plt.show()

# %% [markdown]
# ## Definition:
#
# $\{x \in X \mid x \succeq y\}$ called the 'at least as good as' set.
#
# $\{x \in X \mid x \preceq y\}$ called the 'no better than' set.
#
# $\{x \in X \mid x \prec y\}$ called the 'worse than' set.
#
# $\{x \in X \mid x \succ y\}$ called the 'preferred to' set.
#
# $\{x \in X \mid x \sim y\}$ called the 'indifference' set.

# %% [markdown]
# $$
# \text{Axiom 4': Local Non-satiation. For all } \bold{x}^0 \in R^n_{+}, \text{ and for all } \varepsilon > 0, \text{ there exists some } \bold{x} \in B_{\varepsilon}\bold{(x^0)} \bigcap R^n_{+} \text{ such that } \bold{x} \succ \bold{x}^0.
# $$

# %%
import matplotlib.pyplot as plt

# Define the set of choices
set_of_choices = [(0, 10), (1, 9), (1.7, 8.6), (1.4, 8.3), (2, 8), (3, 7), (3.1, 6.9)]
x, y = zip(*set_of_choices)

plt.figure(figsize=(10, 6))

# Plot dashed lines for non-continuous connections
plt.plot([1, 1.7], [9, 8.6], linestyle='-', color='blue')
plt.plot([1.7, 2], [8.6, 8], linestyle='-', color='blue')

# Plot continuous lines for continuous connections and label them
plt.plot([0, 1], [10, 9], linestyle='-', color='blue', label=r'$\mathbf{x}^0$')
plt.plot([2, 3], [8, 7], linestyle='-', color='blue')
plt.plot([3, 3.1], [7, 6.9], linestyle='-', color='blue')

plt.text(2.5, 9, r'$\succ \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(0.5, 8, r'$\prec \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(2, 8, r'$\mathbf{x}^0$', fontsize=12, color='black', ha='right', va='top')

# Fill the area above the blue line with yellow
plt.fill_between([0, 1, 1.7, 2, 3, 3.1], [10, 9, 8.6, 8, 7, 6.9], 10, color='yellow', alpha=0.3)

# Fill the area below the blue line with pink
plt.fill_between([0, 1, 1.7, 2, 3, 3.1], [10, 9, 8.6, 8, 7, 6.9], 6.9, color='pink', alpha=0.3)

# Set the limits to attach lines to the axes
plt.xlim(left=0)
plt.ylim(bottom=6.9)

# Set the title and labels
plt.title("Indifference curve based on\ncompleteness, transitivity, and continuity axioms")
plt.xlabel('$x^1$')
plt.ylabel('$x^2$')

plt.xticks([]) 
plt.yticks([])

# Grid and legend adjustments
plt.grid(False)
plt.legend(loc='upper left')  # Position the legend at the top left

# Show the plot
plt.show()

# %%
set_of_choices = [(0, 10), (1, 9), (1.7, 8.6), (1.4, 8.3), (2, 8), (3, 7), (3.1, 6.9)]
x, y = zip(*set_of_choices)

plt.figure(figsize=(10, 6))

# Plot dashed lines for non-continuous connections
plt.plot([1, 1.7], [9, 8.6], linestyle='-', color='blue')
plt.plot([1.7, 2], [8.6, 8], linestyle='-', color='blue')

# Plot continuous lines for continuous connections and label them
plt.plot([0, 1], [10, 9], linestyle='-', color='blue')
plt.plot([2, 3], [8, 7], linestyle='-', color='blue')
plt.plot([3, 3.1], [7, 6.9], linestyle='-', color='blue')

# Add text annotations
plt.scatter(2, 8, color='#549A40')
plt.annotate(r'$\mathbf{x}^0$', (2, 8), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')
plt.scatter(1.7, 8.6, color='#549A40')
plt.annotate(r'$\mathbf{x}^1$', (1.7, 8.6), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')

# Set the limits to attach lines to the axes
plt.xlim(left=0)
plt.ylim(bottom=6.9)

# Set the title and labels
plt.axvline(2, linestyle='--')
plt.axhline(8, linestyle='--')
plt.title("Indifference curve based on\ncompleteness, transitivity, and continuity axioms")
plt.xlabel('$x^1$')
plt.ylabel('$x^2$')

# Grid and legend adjustments
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# $$
# \text{Axiom 4: Strict Monotonicity. For all } \bold{x}^0, \bold{x}^1 \in R^n_{+}, \text{ if } \bold{x}^0 \geq \bold{x}^1 \text{ then } \bold{x}^0 \succsim \bold{x}^1, \text{ while if } \bold{x}^0 \gg \bold{x}^1, \text{ then } \bold{x}^0 \succ \bold{x}^1.
# $$

# %%
set_of_choices = [(0, 10), (1, 9), (1.7, 8.6), (1.4, 8.3), (2, 8), (3, 7), (3.1, 6.9)]
x, y = zip(*set_of_choices)

plt.figure(figsize=(10, 6))

# Plot dashed lines for non-continuous connections
plt.plot([1, 1.7], [9, 8.6], 2, linestyle='-', color='blue')
plt.plot([1.7, 2], [8.6, 8], 4, linestyle='-', color='blue')

# Plot continuous lines for continuous connections and label them
plt.plot([0, 1], [10, 9], linestyle='-', color='blue')
plt.plot([2, 3], [8, 7], linestyle='-', color='blue')
plt.plot([3, 3.1], [7, 6.9], linestyle='-', color='blue')
plt.plot([2, 1], [8, 9], linestyle='--', color='red')

# Fill the area above the blue line with yellow
plt.fill_between([0, 1, 1.7, 2, 3, 3.1], [10, 9, 8.6, 8, 7, 6.9], 10, color='yellow', alpha=0.3)

# Fill the area below the blue line with pink
plt.fill_between([0, 1, 1.7, 2, 3, 3.1], [10, 9, 8.6, 8, 7, 6.9], 6.9, color='pink', alpha=0.3)

# Add text annotations
plt.scatter(2, 8, color='#549A40')
plt.annotate(r'$\mathbf{x}^0$', (2, 8), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')
plt.scatter(1.7, 8.6, color='#549A40')
plt.annotate(r'$\mathbf{x}^1$', (1.7, 8.6), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')
plt.scatter(1, 9, color='#549A40')
plt.annotate(r'$\mathbf{x}^2$', (1, 9), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')
plt.scatter(1.5, 8.5, color='#549A40')
plt.annotate(r'$\mathbf{x}^t$', (1.5, 8.5), textcoords="offset points", xytext=(0,8), ha='center', fontsize=12, color='black')


plt.text(2.5, 9, r'$\succ \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')
plt.text(0.5, 8, r'$\prec \mathbf{x}^0$', fontsize=12, color='black', ha='center', va='center')

# Set the limits to attach lines to the axes
plt.xlim(left=0)
plt.ylim(bottom=6.9)

plt.title("Indifference curve based on\ncompleteness, transitivity, and continuity axioms")
plt.xlabel('$x^1$')
plt.ylabel('$x^2$')

# Grid and legend adjustments
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# $$
# \text{Axiom 5': Convexity. if } \bold{x}^0 \succsim \bold{x}^1, \text{ then } t\bold{x}^1 + (1 - t)\bold{x}^0 \succsim \bold{x}^0 \text{ for all } t \in [0, 1].
# $$

# %% [markdown]
# $$
# \text{Axiom 5: Strict Convexity. if } \bold{x}^1 \neq \bold{x}^0 \text{ and } \bold{x}^1 \succsim \bold{x}^0, \text{ then } t\bold{x}^1 + (1 - t)\bold{x}^0 \succ \bold{x}^0 \text{ for all } t \in (0, 1).
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# Define the set of choices to form a convex indifference curve
set_of_choices = [(0, 10), (1, 8), (2, 6.5), (3, 5.5), (4, 5), (5, 4.8)]

# Extract x and y coordinates
x, y = zip(*set_of_choices)

# Sort the coordinates based on x values
sorted_pairs = sorted(zip(x, y))
x_sorted, y_sorted = zip(*sorted_pairs)

# Generate a smooth curve
x_smooth = np.linspace(min(x_sorted), max(x_sorted), 300)  # More points for a smoother curve
spl = make_interp_spline(x_sorted, y_sorted, k=3)  # B-spline with degree 3
y_smooth = spl(x_smooth)

# Plot the points and the smooth curve
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='#549A40')
plt.plot(x_smooth, y_smooth, color='blue', linestyle='-')

plt.plot([1, 3], [8, 5.5], linestyle='--', color='red')
plt.scatter(1.72, 7.1, color='#549A40')
plt.annotate(r'$\mathbf{x}^t$', (1.72, 7.1), textcoords="offset points", xytext=(0,8), ha='center', fontsize=12, color='black')

plt.annotate(r'$\mathbf{x}^1$', (3, 5.5), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')
plt.annotate(r'$\mathbf{x}^2$', (1, 8), textcoords="offset points", xytext=(0,10), ha='center', fontsize=12, color='black')

plt.plot([4, 2.5], [5, 5.5], linestyle='-', color='black')
plt.plot([0.5, 1.2], [8.91, 7.5], linestyle='-', color='black')


# Set the title and labels
plt.title("Indifference Curve")
plt.xlabel('Number of first goods in bundles')
plt.ylabel('Number of second goods in bundles')

# Grid and legend adjustments
plt.grid(True)
plt.legend(loc='upper left')  # Position the legend at the top left

# Show the plot
plt.show()
# Out:
# C:\Users\Mj\AppData\Local\Temp\ipykernel_2684\658893015.py:43: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='upper left')  # Position the legend at the top left
