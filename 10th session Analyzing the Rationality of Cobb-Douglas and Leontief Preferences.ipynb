# %% [markdown]
# # 10th Session

# %% [markdown]
# # Analyzing the Rationality of Cobb-Douglas and Leontief Preferences

# %% [markdown]
# - We are going to analyze whether Cobb-Douglas and Leontief preferences satisfy the axioms of rationality or not.

# %% [markdown]
# # Cobb-douglas Preferences

# %% [markdown]
# $$ U(x, y) = x^{\alpha} y^{1-\alpha}$$

# %%
def Cobb_Douglas(x, y):
    alpha = 0.5
    beta = 1 - alpha  
    return x ** alpha * y ** beta

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1 ,1000)  
y = np.arange(1 ,1000)  

X, Y = np.meshgrid(x, y)
Z = Cobb_Douglas(X, Y)

fig = plt.figure(figsize = (12, 5))

ax1 = fig.add_subplot(121, projection = "3d")
ax1.plot_surface(X, Y, Z, cmap = "Wistia")
ax1.set_title("Cobb_Douglas Utility Function")
ax1.set_xlabel("Good X")
ax1.set_ylabel("Good Y")
ax1.set_zlabel("Utility Levels")
ax1.grid(False)

ax2 = fig.add_subplot(122)
contour = plt.contour(X, Y, Z, levels=5, cmap='spring')
plt.colorbar(contour)
ax2.set_title("Contour Plot of Cobb_Douglas Utility Function")
ax2.set_xlabel("Good X")
ax2.set_ylabel("Good Y")
ax2.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Leontief Preferences

# %% [markdown]
# $$ U(x, y)= min(\frac{x}{w_1}, \frac{y}{w_2})$$

# %%
def Leontief(x, y):
    w1 = 1
    w2 = 1
    return np.minimum(w1 * x, w2 * y)

# %%
x = np.arange(1 ,1000)  
y = np.arange(1 ,1000)  

X, Y = np.meshgrid(x, y)
Z = Leontief(X, Y)

fig = plt.figure(figsize = (12, 5))

ax1 = fig.add_subplot(121, projection = "3d")
ax1.plot_surface(X, Y, Z, cmap = "viridis")
ax1.set_title("Leontief Utility Function")
ax1.set_xlabel("Good X")
ax1.set_ylabel("Good Y")
ax1.set_zlabel("Utility Levels")
ax1.grid(False)

ax2 = fig.add_subplot(122)
contour = plt.contour(X, Y, Z, levels=5, cmap='spring')
plt.colorbar(contour)
ax2.set_title("Contour Plot of Leontief Utility Function")
ax2.set_xlabel("Good X")
ax2.set_ylabel("Good Y")
ax2.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Defining baskests and calculating utilities with both functions

# %%
basket_1 = np.array([30, 60])
basket_2 = np.array([10, 20])
basket_3 = np.array([5, 10])

# %%
from colored import Fore, Back, Style

U1_Cobb_Douglas = Cobb_Douglas(basket_1[0], basket_1[1])
U2_Cobb_Douglas = Cobb_Douglas(basket_2[0], basket_2[1])
U3_Cobb_Douglas = Cobb_Douglas(basket_3[0], basket_3[1])

print(f'{Fore.black}{Back.white} Utility of the first basket based on the Cobb Douglas utility function is {Fore.red}{U1_Cobb_Douglas}')
print(f'{Style.BOLD}{Fore.black}{Back.yellow} Utility of the second basket based on the Cobb Douglas utility function is {Fore.red}{U2_Cobb_Douglas} ')
print(f'{Style.underline_color(1)}{Fore.black}{Back.magenta} Utility of the third basket based on the Cobb Douglas utility function is {Fore.black}{U3_Cobb_Douglas} ')
# Out:
#  Utility of the first basket based on the Cobb Douglas utility function is 42.42640687119285
#  Utility of the second basket based on the Cobb Douglas utility function is 14.142135623730953
#  Utility of the third basket based on the Cobb Douglas utility function is 7.071067811865476

# %%
U1_leontief = Leontief(basket_1[0], basket_1[1])
U2_leontief = Leontief(basket_2[0], basket_2[1])
U3_leontief = Leontief(basket_3[0], basket_3[1])

print(f'{Fore.black}{Back.white} Utility of the first basket based on the Leontief utility function is {Fore.red}{U1_leontief}')
print(f'{Style.BOLD}{Fore.black}{Back.yellow} Utility of the second basket based on the Leontief utility function is {Fore.red}{U2_leontief} ')
print(f'{Style.underline_color(1)}{Fore.black}{Back.magenta} Utility of the third basket based on the Leontief utility function is {Fore.black}{U3_leontief} ')
# Out:
#  Utility of the first basket based on the Leontief utility function is 30
#  Utility of the second basket based on the Leontief utility function is 10
#  Utility of the third basket based on the Leontief utility function is 5

# %% [markdown]
# ### Cobb Douglas Satisfying Completeness:

# %%
if U1_Cobb_Douglas > U2_Cobb_Douglas:
    print("Basket 1 is preferred over Basket 2")
elif U1_Cobb_Douglas < U2_Cobb_Douglas:
    print("Basket 2 is preferred over Basket 1")
else:
    print("Consumer is indifferent between Basket 1 and Basket 2")

if U1_Cobb_Douglas > U3_Cobb_Douglas:
    print("Basket 1 is preferred over Basket 3")
elif U1_Cobb_Douglas < U3_Cobb_Douglas:
    print("Basket 3 is preferred over Basket 1")
else:
    print("Consumer is indifferent between Basket 1 and Basket 3")

if U2_Cobb_Douglas > U3_Cobb_Douglas:
    print("Basket 2 is preferred over Basket 3")
elif U2_Cobb_Douglas < U3_Cobb_Douglas:
    print("Basket 3 is preferred over Basket 2")
else:
    print("Consumer is indifferent between Basket 2 and Basket 3")
# Out:
# Basket 1 is preferred over Basket 2
# Basket 1 is preferred over Basket 3
# Basket 2 is preferred over Basket 3

# %% [markdown]
# ### Leontief Satisfying Completeness:

# %%
if U1_leontief > U2_leontief:
    print("Basket 1 is preferred over Basket 2")
elif U1_leontief < U2_leontief:
    print("Basket 2 is preferred over Basket 1")
else:
    print("Consumer is indifferent between Basket 1 and Basket 2")

if U1_leontief > U3_leontief:
    print("Basket 1 is preferred over Basket 3")
elif U1_leontief < U3_leontief:
    print("Basket 3 is preferred over Basket 1")
else:
    print("Consumer is indifferent between Basket 1 and Basket 3")

if U2_leontief > U3_leontief:
    print("Basket 2 is preferred over Basket 3")
elif U2_leontief < U3_leontief:
    print("Basket 3 is preferred over Basket 2")
else:
    print("Consumer is indifferent between Basket 2 and Basket 3")
# Out:
# Basket 1 is preferred over Basket 2
# Basket 1 is preferred over Basket 3
# Basket 2 is preferred over Basket 3

# %% [markdown]
# ## Satisfying Transitivity:

# %%
def check_transitivity(U1, U2, U3):
    if U1 > U2 and U2 > U3:
        return "Transitivity is satisfied: U1 > U2 > U3"
    elif U1 < U2 and U2 < U3:
        return "Transitivity is satisfied: U1 < U2 < U3"
    else:
        return "Transitivity is not satisfied"

# %%
result_of_cb = check_transitivity(U1_Cobb_Douglas, U2_Cobb_Douglas, U3_Cobb_Douglas)
print(f'Cobb-Douglas utility function satisfies transitivity: {result_of_cb}')
# Out:
# Cobb-Douglas utility function satisfies transitivity: Transitivity is satisfied: U1 > U2 > U3

# %%
result_of_leon = check_transitivity(U1_leontief, U2_leontief, U3_leontief)
print(f'Leontief utility function satifies transitvity: {result_of_leon}')
# Out:
# Leontief utility function satifies transitvity: Transitivity is satisfied: U1 > U2 > U3

# %% [markdown]
# ### Cobb douglas Satisfies Continuity:

# %%
basket_1_with_small_change = np.array([30.01, 60.01])
basket_2_with_small_change = np.array([10.01, 20.01])
basket_3_with_small_change = np.array([5.01, 10.01])

# %%
U1_with_small_change = Cobb_Douglas(basket_1_with_small_change[0], basket_1_with_small_change[1])
U2_with_small_change = Cobb_Douglas(basket_2_with_small_change[0], basket_2_with_small_change[1])
U3_with_small_change = Cobb_Douglas(basket_3_with_small_change[0], basket_3_with_small_change[1])

print(f' U1: {U1_Cobb_Douglas} vs U1 with small change: {U1_with_small_change}')
print(f' U2: {U2_Cobb_Douglas} vs U2 with small change: {U2_with_small_change}')
print(f' U3: {U3_Cobb_Douglas} vs U3 with small change: {U3_with_small_change}')
# Out:
#  U1: 42.42640687119285 vs U1 with small change: 42.43701332563356
#  U2: 14.142135623730953 vs U2 with small change: 14.152741783838213
#  U3: 7.071067811865476 vs U3 with small change: 7.081673531023582

# %% [markdown]
# ### Leontief satisfies continuity:

# %%
U1_leontief_small_change = Leontief(basket_1_with_small_change[0], basket_1_with_small_change[1])
U2_leontief__small_change = Leontief(basket_2_with_small_change[0], basket_2_with_small_change[1])
U3_leontief__small_change = Leontief(basket_3_with_small_change[0], basket_3_with_small_change[1])

print(f' U1: {U1_leontief} vs U1 with small change: {U1_leontief_small_change}')
print(f' U2: {U2_leontief} vs U2 with small change: {U2_leontief__small_change}')
print(f' U3: {U3_leontief} vs U3 with small change: {U3_leontief__small_change}')
# Out:
#  U1: 30 vs U1 with small change: 30.01
#  U2: 10 vs U2 with small change: 10.01
#  U3: 5 vs U3 with small change: 5.01

# %% [markdown]
# ## Satisfying Monotonicity:
# - **Increasing both goods yields higher utility that initial basket**

# %%
basket_1_with_increase_in_x_and_y = np.array([31, 61])
basket_2_with_increase_in_x_and_y = np.array([11, 21])
basket_3_with_increase_in_x_and_y = np.array([6, 11])

# %% [markdown]
# ### Cobb douglas:

# %%
U1_with_increase_in_x_and_y = Cobb_Douglas(basket_1_with_increase_in_x_and_y[0], basket_1_with_increase_in_x_and_y[1])
U2_with_increase_in_x_and_y = Cobb_Douglas(basket_2_with_increase_in_x_and_y[0], basket_2_with_increase_in_x_and_y[1])
U3_with_increase_in_x_and_y = Cobb_Douglas(basket_3_with_increase_in_x_and_y[0], basket_3_with_increase_in_x_and_y[1])

print(f'After an in increase in x and y in first basket from {basket_1} to {basket_1_with_increase_in_x_and_y}, the utility increased from {U1_Cobb_Douglas} to {U1_with_increase_in_x_and_y}: {U1_Cobb_Douglas < U1_with_increase_in_x_and_y}')
print(f'After an in increase in x and y in second basket from {basket_2} to {basket_2_with_increase_in_x_and_y}, the utility increased from {U2_Cobb_Douglas} to {U2_with_increase_in_x_and_y}: {U2_Cobb_Douglas < U2_with_increase_in_x_and_y}')
print(f'After an in increase in x and y in third basket from {basket_3} to {basket_3_with_increase_in_x_and_y}, the utility increased from {U3_Cobb_Douglas} to {U3_with_increase_in_x_and_y}: {U3_Cobb_Douglas < U3_with_increase_in_x_and_y}')
# Out:
# After an in increase in x and y in first basket from [30 60] to [31 61], the utility increased from 42.42640687119285 to 43.485629810317796: True
# After an in increase in x and y in second basket from [10 20] to [11 21], the utility increased from 14.142135623730953 to 15.198684153570662: True
# After an in increase in x and y in third basket from [ 5 10] to [ 6 11], the utility increased from 7.071067811865476 to 8.124038404635959: True

# %% [markdown]
# ### Leontief:

# %%
U1_leontief_increase_in_both = Leontief(basket_1_with_increase_in_x_and_y[0], basket_1_with_increase_in_x_and_y[1])
U2_leontief_increase_in_both = Leontief(basket_2_with_increase_in_x_and_y[0], basket_2_with_increase_in_x_and_y[1])
U3_leontief_increase_in_both = Leontief(basket_3_with_increase_in_x_and_y[0], basket_3_with_increase_in_x_and_y[1])

print(f'After an increase in both goods in first basket from {basket_1} to {basket_1_with_increase_in_x_and_y}, the utility increased from {U1_leontief} to {U1_leontief_increase_in_both}: {U1_leontief < U1_leontief_increase_in_both}')
print(f'After an increase in both goods in second basket from {basket_2} to {basket_2_with_increase_in_x_and_y}, the utility increased from {U2_leontief} to {U2_leontief_increase_in_both}: {U2_leontief < U2_leontief_increase_in_both}')
print(f'After an increase in both goods in third basket from {basket_3} to {basket_3_with_increase_in_x_and_y}, the utility increased from {U3_leontief} to {U3_leontief_increase_in_both}: {U3_leontief < U3_leontief_increase_in_both}')
# Out:
# After an increase in both goods in first basket from [30 60] to [31 61], the utility increased from 30 to 31: True
# After an increase in both goods in second basket from [10 20] to [11 21], the utility increased from 10 to 11: True
# After an increase in both goods in third basket from [ 5 10] to [ 6 11], the utility increased from 5 to 6: True

# %% [markdown]
# ## Satisfying Strict Monotonicity:
# **Increasing one good yields higher utility that initial basket (increasing Y in this case)**

# %% [markdown]
# ### Cobb douglas

# %%
basket_1_with_increase_in_y = np.array([30, 65])
basket_2_with_increase_in_y = np.array([10, 25])
basket_3_with_increase_in_y = np.array([5, 15])

U1_with_increase_in_y = Cobb_Douglas(basket_1_with_increase_in_y[0], basket_1_with_increase_in_y[1])
U2_with_increase_in_y = Cobb_Douglas(basket_2_with_increase_in_y[0], basket_2_with_increase_in_y[1])
U3_with_increase_in_y = Cobb_Douglas(basket_3_with_increase_in_y[0], basket_3_with_increase_in_y[1])

print(f'After an in increase in x in first basket from {basket_1} to {basket_1_with_increase_in_y}, the utility increased from {U1_Cobb_Douglas} to {U1_with_increase_in_y}: {U1_Cobb_Douglas < U1_with_increase_in_y}')
print(f'After an in increase in x in second basket from {basket_2} to {basket_2_with_increase_in_y}, the utility increased from {U2_Cobb_Douglas} to {U2_with_increase_in_y}: {U2_Cobb_Douglas < U2_with_increase_in_y}')
print(f'After an in increase in x in third basket from {basket_3} to {basket_3_with_increase_in_y}, the utility increased from {U3_Cobb_Douglas} to {U3_with_increase_in_y}: {U3_Cobb_Douglas < U3_with_increase_in_y}')
# Out:
# After an in increase in x in first basket from [30 60] to [30 65], the utility increased from 42.42640687119285 to 44.15880433163923: True
# After an in increase in x in second basket from [10 20] to [10 25], the utility increased from 14.142135623730953 to 15.811388300841898: True
# After an in increase in x in third basket from [ 5 10] to [ 5 15], the utility increased from 7.071067811865476 to 8.660254037844387: True

# %% [markdown]
# ### Leontief:

# %%
U1_leontief_increase_y = Leontief(basket_1_with_increase_in_y[0], basket_1_with_increase_in_y[1])
U2_leontief_increase_y  = Leontief(basket_2_with_increase_in_y[0], basket_2_with_increase_in_y[1])
U3_leontief_increase_y = Leontief(basket_3_with_increase_in_y[0], basket_3_with_increase_in_y[1])

print(f'After an increase in x in first basket from {basket_1} to {basket_1_with_increase_in_y}, the utility increased from {U1_leontief} to {U1_leontief_increase_y}: {U1_leontief < U1_leontief_increase_y}')
print(f'After an increase in x in second basket from {basket_2} to {basket_2_with_increase_in_y}, the utility increased from {U2_leontief} to {U2_leontief_increase_y}: {U2_leontief < U2_leontief_increase_y}')
print(f'After an increase in x in third basket from {basket_3} to {basket_3_with_increase_in_y}, the utility increased from {U3_leontief} to {U3_leontief_increase_y}: {U3_leontief < U3_leontief_increase_y}')
# Out:
# After an increase in x in first basket from [30 60] to [30 65], the utility increased from 30 to 30: False
# After an increase in x in second basket from [10 20] to [10 25], the utility increased from 10 to 10: False
# After an increase in x in third basket from [ 5 10] to [ 5 15], the utility increased from 5 to 5: False

# %% [markdown]
# # 1st Conclusion: Leontief preferences are not strictly monotonic

# %% [markdown]
# ## Satisfying Convexity:
# **The mixture of two baskets is as good as one basket**
#
# **I will check two baskets that have equivalent utilities**

# %% [markdown]
# ### Cobb douglas

# %%
basket_11 = np.array([8, 8])
basket_22 = np.array([4, 16])

U_basket_11 = Cobb_Douglas(basket_11[0], basket_11[1])
U_basket_22 = Cobb_Douglas(basket_22[0], basket_22[1])
print(f'utility of the first basket is {U_basket_11}')
print(f'utility of the second basket is {U_basket_22}')
# Out:
# utility of the first basket is 8.000000000000002
# utility of the second basket is 8.0

# %%
t = 0.5

mixed_x_from_basket1_and_basket2 = t * basket_11[0] + (1-t) * basket_22[0]
mixed_y_from_basket1_and_basket2 = t * basket_11[1] + (1-t) * basket_22[1]

U_mixed = Cobb_Douglas(mixed_x_from_basket1_and_basket2, mixed_y_from_basket1_and_basket2)

print(f'utility of the mixed basket is {U_mixed}')
print(f'convexity is satisfied (between mixture and first basket): {U_mixed >= U_basket_11}')
print(f'convexity is satisfied (between mixture and second basket): {U_mixed >= U_basket_22}')
# Out:
# utility of the mixed basket is 8.48528137423857
# convexity is satisfied (between mixture and first basket): True
# convexity is satisfied (between mixture and second basket): True

# %% [markdown]
# ### Leontief:

# %%
eq_bundle1 = [30, 60]
eq_bundle2 = [30, 50]

U_eq_bundle1 = Leontief(eq_bundle1[0], eq_bundle1[1])
U_eq_bundle2 = Leontief(eq_bundle2[0], eq_bundle2[1])
print(f'utility of the first bundle is {U_eq_bundle1}')
print(f'utility of the second bundle is {U_eq_bundle2}')
# Out:
# utility of the first bundle is 30
# utility of the second bundle is 30

# %%
mixx = t * eq_bundle1[0] + (1-t) * eq_bundle2[0]
mixy = t * eq_bundle1[1] + (1-t) * eq_bundle2[1]

umix = Leontief(mixx, mixy)

print(f'utility of the mixed basket is {umix}')
print(f'convexity is satisfied (between mixture and first basket): {umix >= U_eq_bundle1}')
print(f'convexity is satisfied (between mixture and second basket): {umix >= U_eq_bundle2}')
# Out:
# utility of the mixed basket is 30.0
# convexity is satisfied (between mixture and first basket): True
# convexity is satisfied (between mixture and second basket): True

# %% [markdown]
# ## Satisfying Strict Convexity:
# **The mixture of two baskets is better one basket**

# %% [markdown]
# ### Cobb douglas:

# %%
print(f'strict convexity is satisfied: {U_mixed > U_basket_11}')
# Out:
# strict convexity is satisfied: True

# %% [markdown]
# ### Leonftief:

# %%
print(f'convexity is satisfied (between mixture and first basket): {umix > U_eq_bundle1}')
print(f'convexity is satisfied (between mixture and second basket): {umix > U_eq_bundle2}')
# Out:
# convexity is satisfied (between mixture and first basket): False
# convexity is satisfied (between mixture and second basket): False

# %% [markdown]
# # 2nd Conclusion: Leontief preferences are not stictly convex
